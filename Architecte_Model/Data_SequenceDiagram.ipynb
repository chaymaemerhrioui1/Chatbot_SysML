# %%
pip install groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.4 MB/s eta 0:00:00

# %%
import requests
import json
import time
import pandas as pd
from collections import deque
import datetime
import sys
import re

# %%
api_key = "**"

# %% [markdown]
# ## function for extract Sections

# %%
def extract_sections(text, sections_to_extract):
    extracted_sections = {}
    current_section = None
    lines = text.split('\n')

    for line in lines:
        for section in sections_to_extract:
            # (# Section) and (**Section:**)
            pattern = r'^\s*((?:#\s+)|(?:\*\*))' + re.escape(section) + r'\s*[:]?(\*\*?|$)'
            if re.match(pattern, line, re.IGNORECASE):
                current_section = section
                extracted_sections[current_section] = []
                break
        if current_section and line.strip() != '':
            if not re.match(r'^\s*((?:#\s+)|(?:\*\*))', line):
                extracted_sections[current_section].append(line.strip())

    return extracted_sections

# %%
class RateLimiter:
    """Manages rate limits for the Groq API"""

    def __init__(self, requests_per_minute=30):
        self.requests_per_minute = requests_per_minute
        self.request_timestamps = deque(maxlen=requests_per_minute)

    def wait_if_needed(self):
        """Waits if necessary to respect the requests per minute limit"""
        current_time = time.time()

        if len(self.request_timestamps) >= self.requests_per_minute:
            oldest_request_time = self.request_timestamps[0]
            time_since_oldest = current_time - oldest_request_time

            if time_since_oldest < 60:
                wait_time = 60 - time_since_oldest + 0.1
                print(f"Rate limit reached, waiting for {wait_time:.2f} seconds...")
                time.sleep(wait_time)

        self.request_timestamps.append(time.time())

# %% [markdown]
# ## Function of Generating Sequence Diagram

# %%
def generate_sequence_diagram(description_dict, rate_limiter):
    url = "https://api.groq.com/openai/v1/chat/completions"

    prompt = f"""You are an expert in UML modeling, specializing in sequence diagrams for automotive systems, particularly ADAS (Advanced Driver Assistance Systems).

    TASK:
    1. Carefully analyze the technical description below, which is divided into sections.
    2. Extract all necessary elements for a complete UML sequence diagram:
       - Participants (driver, ADAS system components, sensors, interfaces)
       - Messages exchanged and their precise chronology
       - Conditions, loops, and alternative paths
    3. Generate valid and complete PlantUML code that accurately represents the system's interaction flow, using single quotes for participant names that contain spaces or special characters.

    TECHNICAL DESCRIPTION:
    """

    for section, content in description_dict.items():
        prompt += f"\n# {section}\n"
        for line in content:
            prompt += f"{line}\n"

    # Additional instructions to handle participant naming
    prompt += f"""

    IMPORTANT NOTES:
    - Use single quotes for participant names that contain spaces or special characters. For example:
        participant "Powertrain System" as Powertrain
      Alternatively, if possible, use CamelCase or underscores to avoid spaces:
        participant PowertrainSystem as Powertrain
    - Ensure that the PlantUML code starts with @startuml and ends with @enduml.
    - Avoid using double quotes for participant names unless necessary.
    """

    payload = {
        "model": "mistral-saba-24b",
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.2,
        "max_tokens": 2048
    }

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}"
    }

    rate_limiter.wait_if_needed()

    max_retries = 3
    for attempt in range(max_retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload))
            response.raise_for_status()

            print(f"Status code: {response.status_code}")
            response_json = response.json()

            if "choices" in response_json and len(response_json["choices"]) > 0:
                uml_code = response_json["choices"][0]["message"]["content"]
                return uml_code
            else:
                print(f"Unusual response: {response_json}")
                if "error" in response_json:
                    print(f"Error: {response_json['error']}")
                return f"UML generation error: {response_json}"

        except requests.exceptions.RequestException as e:
            print(f"Attempt {attempt+1} failed: {e}")
            if attempt < max_retries - 1:
                if "429" in str(e):
                    wait_time = 60 + 2 ** attempt
                    print(f"Rate limit error. Waiting for {wait_time} seconds...")
                else:
                    wait_time = 2 ** attempt
                    print(f"Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                return f"Failed after {max_retries} attempts: {str(e)}"

# %% [markdown]
# ## Process The Output

# %%
def process_csv_batch(file_path, batch_size=20, start_from=0):
    """Processes the CSV in batches without creating a progression file"""

    try:
        df = pd.read_csv(file_path)
        total_rows = len(df)

        print(f"File loaded successfully: {total_rows} entries found")
        rate_limiter = RateLimiter(requests_per_minute=25)
        start_idx = start_from
        end_idx = min(start_idx + batch_size, total_rows)
        print(f"Processing lines {start_idx} to {end_idx-1}")
        results = []
        output_file = f"uml_sequence_diagrams.csv"

        for index in range(start_idx, end_idx):
            row = df.iloc[index]
            try:
                print(f"Processing line {index}...")
                if 'Output' not in row:
                    print(f"Error: 'Output' column not found in line {index}")
                    print(f"Available columns: {row.index.tolist()}")
                    continue

                description = row['Output']
                if pd.isna(description) or not description.strip():
                    print(f"Line {index}: empty or invalid description, skipped")
                    continue

                sections = extract_sections(description, sections_to_extract=[
                    "Technical Details",
                    "Operational Steps",
                    "Interactions with Components and Systems",
                    "Necessary Conditions",
                    "User Interface and Controls",
                    "Fault Detection and Management"
                ])

                structured_description = ""
                for section, content in sections.items():
                    structured_description += f"# {section}\n"
                    for line in content:
                        structured_description += f"{line}\n"
                    structured_description += "\n"

                uml_content = generate_sequence_diagram(sections, rate_limiter)
                uml_structure = ""
                uml_code = ""

                if "```" in uml_content:
                    parts = uml_content.split("```")
                    uml_structure = parts[0].strip()
                    if len(parts) > 2:
                        uml_code = parts[1].strip()
                else:
                    uml_structure = uml_content

                result_dict = {
                    'index': index,
                    'description': structured_description.strip(),
                    'uml_code': uml_code
                }

                if 'ID' in row:
                    result_dict['ID'] = row['ID']

                results.append(result_dict)
                if index % 5 == 0 or index == end_idx - 1:
                    temp_df = pd.DataFrame(results)
                    temp_df.to_csv(output_file, index=False)
                    print(f"Progress saved: {len(results)}/{end_idx-start_idx} lines processed")

            except Exception as e:
                print(f"Error processing line {index}: {str(e)}")
                with open("errors_processing.log", "a") as log:
                    log.write(f"{datetime.datetime.now()} - Error line {index}: {str(e)}\n")
                continue

        if results:
            output_df = pd.DataFrame(results)
            output_df.to_csv(output_file, index=False)
            print(f"Results saved in '{output_file}'")
        else:
            print("No results to save")

        return end_idx, total_rows

    except Exception as e:
        print(f"Critical error processing the CSV: {str(e)}")
        return start_from, 0

# %%
if __name__ == "__main__":
    FILE_PATH = 'Dataset_ACC.csv'
    BATCH_SIZE = 500

    start_from = 0
    if len(sys.argv) > 1:
        try:
            start_from = int(sys.argv[1])
        except ValueError:
            print(f"Invalid argument for starting point: {sys.argv[1]}, using 0 by default.")

    current_position, total = process_csv_batch(FILE_PATH, BATCH_SIZE, start_from)

    if total > 0:
        print(f"Processing completed: {current_position}/{total} entries ({current_position/total*100:.1f}%)")

        if current_position < total:
            print(f"\nTo continue processing from the next entry, run:")
            print(f"python {sys.argv[0]} {current_position}")
# Out:
# Invalid argument for starting point: -f, using 0 by default.
# File loaded successfully: 1000 entries found
# Processing lines 0 to 499
# Processing line 0...
# Status code: 200
# Progress saved: 1/500 lines processed
# Processing line 1...
# Status code: 200
# Processing line 2...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 3...
# Status code: 200
# Processing line 4...
# Status code: 200
# Processing line 5...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 6/500 lines processed
# Processing line 6...
# Status code: 200
# Processing line 7...
# Status code: 200
# Processing line 8...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 9...
# Status code: 200
# Processing line 10...
# Status code: 200
# Progress saved: 11/500 lines processed
# Processing line 11...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 12...
# Status code: 200
# Processing line 13...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 14...
# Status code: 200
# Processing line 15...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 16/500 lines processed
# Processing line 16...
# Status code: 200
# Processing line 17...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 18...
# Status code: 200
# Processing line 19...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 20...
# Status code: 200
# Progress saved: 21/500 lines processed
# Processing line 21...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 22...
# Status code: 200
# Processing line 23...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 24...
# Status code: 200
# Processing line 25...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 26/500 lines processed
# Processing line 26...
# Status code: 200
# Processing line 27...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 28...
# Status code: 200
# Processing line 29...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 30...
# Status code: 200
# Progress saved: 31/500 lines processed
# Processing line 31...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 32...
# Status code: 200
# Processing line 33...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 34...
# Status code: 200
# Processing line 35...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 36/500 lines processed
# Processing line 36...
# Status code: 200
# Processing line 37...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 38...
# Status code: 200
# Processing line 39...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 40...
# Status code: 200
# Progress saved: 41/500 lines processed
# Processing line 41...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 42...
# Status code: 200
# Processing line 43...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 44...
# Status code: 200
# Processing line 45...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 46/500 lines processed
# Processing line 46...
# Status code: 200
# Processing line 47...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 48...
# Status code: 200
# Processing line 49...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 50...
# Status code: 200
# Progress saved: 51/500 lines processed
# Processing line 51...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 52...
# Status code: 200
# Processing line 53...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 54...
# Status code: 200
# Processing line 55...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 56/500 lines processed
# Processing line 56...
# Status code: 200
# Processing line 57...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 58...
# Status code: 200
# Processing line 59...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 60...
# Status code: 200
# Progress saved: 61/500 lines processed
# Processing line 61...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 62...
# Status code: 200
# Processing line 63...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 64...
# Status code: 200
# Processing line 65...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 66/500 lines processed
# Processing line 66...
# Status code: 200
# Processing line 67...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 68...
# Status code: 200
# Processing line 69...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 70...
# Status code: 200
# Progress saved: 71/500 lines processed
# Processing line 71...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 72...
# Status code: 200
# Processing line 73...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 74...
# Status code: 200
# Processing line 75...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 76/500 lines processed
# Processing line 76...
# Status code: 200
# Processing line 77...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 78...
# Status code: 200
# Processing line 79...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 80...
# Status code: 200
# Progress saved: 81/500 lines processed
# Processing line 81...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 82...
# Status code: 200
# Processing line 83...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 84...
# Status code: 200
# Processing line 85...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 86/500 lines processed
# Processing line 86...
# Status code: 200
# Processing line 87...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 88...
# Status code: 200
# Processing line 89...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 90...
# Status code: 200
# Progress saved: 91/500 lines processed
# Processing line 91...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 92...
# Status code: 200
# Processing line 93...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 94...
# Status code: 200
# Processing line 95...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 96/500 lines processed
# Processing line 96...
# Status code: 200
# Processing line 97...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 98...
# Status code: 200
# Processing line 99...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 100...
# Status code: 200
# Progress saved: 101/500 lines processed
# Processing line 101...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 102...
# Status code: 200
# Processing line 103...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 104...
# Status code: 200
# Processing line 105...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 106/500 lines processed
# Processing line 106...
# Status code: 200
# Processing line 107...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 108...
# Status code: 200
# Processing line 109...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 110...
# Status code: 200
# Progress saved: 111/500 lines processed
# Processing line 111...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 112...
# Status code: 200
# Processing line 113...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 114...
# Status code: 200
# Processing line 115...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 116/500 lines processed
# Processing line 116...
# Status code: 200
# Processing line 117...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 118...
# Status code: 200
# Processing line 119...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 120...
# Status code: 200
# Progress saved: 121/500 lines processed
# Processing line 121...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 122...
# Status code: 200
# Processing line 123...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 124...
# Status code: 200
# Processing line 125...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 126/500 lines processed
# Processing line 126...
# Status code: 200
# Processing line 127...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 128...
# Status code: 200
# Processing line 129...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 130...
# Status code: 200
# Progress saved: 131/500 lines processed
# Processing line 131...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 132...
# Status code: 200
# Processing line 133...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 134...
# Status code: 200
# Processing line 135...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 136/500 lines processed
# Processing line 136...
# Status code: 200
# Processing line 137...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 138...
# Status code: 200
# Processing line 139...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 140...
# Status code: 200
# Progress saved: 141/500 lines processed
# Processing line 141...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 142...
# Status code: 200
# Processing line 143...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 144...
# Status code: 200
# Processing line 145...
# Status code: 200
# Progress saved: 146/500 lines processed
# Processing line 146...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 147...
# Status code: 200
# Processing line 148...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 149...
# Status code: 200
# Processing line 150...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 151/500 lines processed
# Processing line 151...
# Status code: 200
# Processing line 152...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 153...
# Status code: 200
# Processing line 154...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 155...
# Status code: 200
# Progress saved: 156/500 lines processed
# Processing line 156...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 157...
# Status code: 200
# Processing line 158...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 159...
# Status code: 200
# Processing line 160...
# Status code: 200
# Progress saved: 161/500 lines processed
# Processing line 161...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 162...
# Status code: 200
# Processing line 163...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 164...
# Status code: 200
# Processing line 165...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 166/500 lines processed
# Processing line 166...
# Status code: 200
# Processing line 167...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 168...
# Status code: 200
# Processing line 169...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 170...
# Status code: 200
# Progress saved: 171/500 lines processed
# Processing line 171...
# Status code: 200
# Processing line 172...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 173...
# Status code: 200
# Processing line 174...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 175...
# Status code: 200
# Progress saved: 176/500 lines processed
# Processing line 176...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 177...
# Status code: 200
# Processing line 178...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 179...
# Status code: 200
# Processing line 180...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 181/500 lines processed
# Processing line 181...
# Status code: 200
# Processing line 182...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 183...
# Status code: 200
# Processing line 184...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 185...
# Status code: 200
# Progress saved: 186/500 lines processed
# Processing line 186...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 187...
# Status code: 200
# Processing line 188...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 189...
# Status code: 200
# Processing line 190...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 191/500 lines processed
# Processing line 191...
# Status code: 200
# Processing line 192...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 193...
# Status code: 200
# Processing line 194...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 195...
# Status code: 200
# Progress saved: 196/500 lines processed
# Processing line 196...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 197...
# Status code: 200
# Processing line 198...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 199...
# Status code: 200
# Processing line 200...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 201/500 lines processed
# Processing line 201...
# Status code: 200
# Processing line 202...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 203...
# Status code: 200
# Processing line 204...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 205...
# Status code: 200
# Progress saved: 206/500 lines processed
# Processing line 206...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 207...
# Status code: 200
# Processing line 208...
# Status code: 200
# Processing line 209...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 210...
# Status code: 200
# Progress saved: 211/500 lines processed
# Processing line 211...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 212...
# Status code: 200
# Processing line 213...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 214...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Status code: 200
# Processing line 215...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 216/500 lines processed
# Processing line 216...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 217...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Status code: 200
# Processing line 218...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 219...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 220...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 221/500 lines processed
# Processing line 221...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 222...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 223...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 224...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 225...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 226/500 lines processed
# Processing line 226...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 227...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 228...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 229...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 230...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 231/500 lines processed
# Processing line 231...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 232...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 233...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 234...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 235...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Progress saved: 236/500 lines processed
# Processing line 236...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 237...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 238...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 239...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 240...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 241/500 lines processed
# Processing line 241...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 242...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 243...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 244...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 245...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 246/500 lines processed
# Processing line 246...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 247...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Status code: 200
# Processing line 248...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 249...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 250...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 251/500 lines processed
# Processing line 251...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 252...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 253...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 254...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 255...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 256/500 lines processed
# Processing line 256...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 257...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Status code: 200
# Processing line 258...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 259...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 260...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Progress saved: 261/500 lines processed
# Processing line 261...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Status code: 200
# Processing line 262...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 263...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Processing line 264...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
# Status code: 200
# Processing line 265...
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 61 seconds...
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.groq.com/openai/v1/chat/completions
# Rate limit error. Waiting for 62 seconds...
